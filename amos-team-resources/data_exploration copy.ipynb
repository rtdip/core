# %%
import pandas as pd
df = pd.read_csv("ShellData.csv")
df.head()
# Out:
# C:\Users\ReneJ\AppData\Local\Temp\ipykernel_24632\246597612.py:2: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("ShellData.csv")
#    Unnamed: 0            TagName                EventTime Status Value
# 0           0  A2PS64V0J.:ZUX09R  2024-01-02 20:03:46.000   Good  0.34
# 1           1  A2PS64V0J.:ZUX09R  2024-01-02 16:00:12.000   Good  0.15
# 2           2  A2PS64V0J.:ZUX09R  2024-01-02 11:56:42.000   Good  0.13
# 3           3  A2PS64V0J.:ZUX09R  2024-01-02 07:53:11.000   Good  0.12
# 4           4  A2PS64V0J.:ZUX09R  2024-01-02 03:49:45.000   Good  0.13

# %%
df["Status"].value_counts()
# Out:
# Status
# Good                 213642667
# Bad                    1347992
# Substituted, Good          253
# Questionable               190
# Name: count, dtype: int64

# %%
df["Value"].value_counts()

# %%
len(df["TagName"].unique())

# %%
import numpy as np
s = df["EventTime"].astype(str)

has_ms = s.str.contains(r"\.\d+$") 
vals   = np.where(has_ms, s, s + ".000")   

df["EventTime_DT"] = pd.to_datetime(vals, format="%Y-%m-%d %H:%M:%S.%f", errors="coerce")

# %%
df

# %%
s = df["Value"].astype(str).str.strip()

mask = ~s.str.match(r"^[+-]?\d+(\.\d+)?([eE][+-]?\d+)?$")

invalid_counts = s[mask].value_counts()

invalid_counts

# %%
t = df[df["Value"] == "Not Connect"]
t

# %%
invalid_counts.sum()

# %%
df2 = df.groupby(df["TagName"])

# %%
df2.EventTime_DT.describe()

# %%
summary = (
    df.groupby("TagName")["EventTime_DT"]
      .agg(['min', 'max'])
      .assign(LengthInDays=lambda x: x["max"] - x["min"])
      .assign(LengthInSeconds=lambda x: (x["max"] - x["min"]).dt.total_seconds())
      .reset_index()
)
summary

# %%
print("Mean: " + str(summary["LengthInDays"].mean()))
print("Median: " + str(summary["LengthInDays"].median()))
print("Mode: " + str(summary["LengthInDays"].mode()))
print("Min: " + str(summary["LengthInDays"].min()))
print("Max: " + str(summary["LengthInDays"].max()))

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,5))
plt.hist(summary["LengthInSeconds"], bins=50)
plt.xlabel("Dauer (Sekunden)")
plt.ylabel("Anzahl Zeitreihen")
plt.title("Verteilung der Zeitreihen-Längen")
plt.tight_layout()
plt.show()

# %%
df_short = summary[summary["LengthInSeconds"] < 2353540.737]

# %%
plt.figure(figsize=(10,5))
plt.hist(df_short["LengthInSeconds"], bins=50)
plt.xlabel("Dauer (Sekunden)")
plt.ylabel("Anzahl Zeitreihen")
plt.title("Verteilung der Zeitreihen-Längen")
plt.tight_layout()
plt.show()

# %%
df["is_numeric"] = pd.to_numeric(df["Value"], errors="coerce").notna()

# %%
table = pd.crosstab(df["Status"], df["is_numeric"])
table.columns = ["String", "Numeric"]
table = table.rename(columns={True: "Numeric", False: "String"})
print(table)

# %%
percent_table = table.div(table.sum(axis=1), axis=0) * 100
print(percent_table.round(2))

# %%
tags_with_strings = (
    df.loc[~df["is_numeric"], "TagName"]
      .dropna()
      .unique()
)
print("Anzahl Tags mit String-Values:", len(tags_with_strings))

# %%
df["EventTime"].dtype
# Out:
# dtype('O')

# %%
df["EventTime"][0]
# Out:
# '2024-01-02 20:03:46.000'

# %%
import numpy as np
s = df["EventTime"].astype(str)

has_ms = s.str.contains(r"\.\d+$")          # hat .fff am Ende
vals   = np.where(has_ms, s, s + ".000")    # fehlende .000 ergänzen

df["EventTime_DT"] = pd.to_datetime(vals, format="%Y-%m-%d %H:%M:%S.%f", errors="coerce")

# %%
df["EventTime"][10550000]
# Out:
# '2024-01-10 05:42:44'

# %%
df
# Out:
#            Unnamed: 0                                        TagName  \
# 0                   0                              A2PS64V0J.:ZUX09R
# 1                   1                              A2PS64V0J.:ZUX09R
# 2                   2                              A2PS64V0J.:ZUX09R
# 3                   3                              A2PS64V0J.:ZUX09R
# 4                   4                              A2PS64V0J.:ZUX09R
# ...               ...                                            ...
# 214991097   214991097                               SHRQHC:2VR_XN7_V
# 214991098   214991098  Ceia3wAoRc35lrPLMr1.lP.xSvRDPiw: K0Fde.sprEeT
# 214991099   214991099     .EF.KiPDrteoLvpar5Td3eePRLd3RRctC0cai:PS.1
# 214991100   214991100                   :oCLE1FqT.3pc5.e0PRK.TriS3RP
# 214991101   214991101               r.ke1PRFLBawEpTPC.KP0:S35c.rR3ie
#
#                          EventTime Status        Value        EventTime_DT
# 0          2024-01-02 20:03:46.000   Good         0.34 2024-01-02 20:03:46
# 1          2024-01-02 16:00:12.000   Good         0.15 2024-01-02 16:00:12
# 2          2024-01-02 11:56:42.000   Good         0.13 2024-01-02 11:56:42
# 3          2024-01-02 07:53:11.000   Good         0.12 2024-01-02 07:53:11
# 4          2024-01-02 03:49:45.000   Good         0.13 2024-01-02 03:49:45
# ...                            ...    ...          ...                 ...
# 214991097  2024-06-29 15:57:58.000    Bad  Calc Failed 2024-06-29 15:57:58
# 214991098  2024-06-29 15:35:41.000    Bad    No Result 2024-06-29 15:35:41
# 214991099  2024-06-29 15:35:41.000    Bad       Failed 2024-06-29 15:35:41
# 214991100  2024-06-29 15:35:41.000    Bad    No Result 2024-06-29 15:35:41
# 214991101  2024-06-29 15:35:41.000    Bad       Failed 2024-06-29 15:35:41
#
# [214991102 rows x 6 columns]

# %%
s = df["Value"].astype(str).str.strip()
mask = ~s.str.match(r"^[+-]?\d+(\.\d+)?([eE][+-]?\d+)?$")
invalid_counts = s[mask].value_counts()

invalid_counts
# Out:
# Value
# Calc Failed      231627
# Bad Input         98155
# nan               74875
# No Result         47516
# Failed            47516
# Out of Serv       43917
# Bad               19920
# Scan Timeout       1452
# Comm Fail           694
# I/O Timeout         208
# Doubtful             41
# Not Connect          34
# Pt Created           12
# Invalid Float         8
# Scan Off              2
# Name: count, dtype: int64

# %%
t = df[df["Value"] == "Not Connect"]
t
# Out:
#            Unnamed: 0                           TagName  \
# 214545234   214545234                  -.H00CPV4V:0P2CV
# 214545235   214545235                 -1190:PVL.2CVI0VP
# 214545236   214545236                 .P7P0C-081:V4VSCP
# 214545237   214545237                 P31:.418PVCV-I0PV
# 214545238   214545238    :V_CdPDU7BVG-G_LRVPOA_3IS.F6PN
# 214545239   214545239                  V7P1I:24VQP0VC.-
# 214545240   214545240  1A._VNVIO0PC:-GVUPR2DB_PS4LG1F_a
# 214545242   214545242                 -C20PV4IPP0.VV1:6
# 214545243   214545243  _OEVaCI_S_VDLGBND-:RGPVUEF.OAA2P
# 214545244   214545244   DS6_1GU_AI.LOGVP-2FRnPV2BVC_:NP
# 214545245   214545245                WDR.0FTLOAC7EO:T18
# 214545247   214545247                LF2:OD8.ART1O0WTEC
# 214545248   214545248   2:F_4I1VDCNLV._GVABURPG_2PPnS-O
# 214545249   214545249                  V4-:PQ11PIV3V.0C
# 214545250   214545250                P4C803VCVC:.P1-4TS
# 214545251   214545251                 I99V-PPLCVV4:01.4
# 214545252   214545252                  1:C.0VVI327P-PVQ
# 214646779   214646779                 P2I1VCV9V.:1L-00P
# 214646781   214646781                .TPCC413V:8SVP0-C4
# 214646783   214646783   ABG2SPDV_FOPUCV:24Rn__V1IPL.GN-
# 214646784   214646784                .RDW082FOL1ACTOT:E
# 214646786   214646786                  VP2-V.0C0CP:0VH4
# 214646787   214646787                  QP.-:0VVV7132ICP
# 214646788   214646788  2L14GO-N:VAP___VR.aFI0V1DBPGSPUC
# 214646789   214646789                 LVCVP9P90:44-.VI1
# 214646792   214646792                  C0.P12:VQPVVI-74
# 214646793   214646793                 VI642P0.-:PVV01PC
# 214646794   214646794                 8CPSV70:-P104CVP.
# 214648081   214648081                COA:T1DRW0OF.7TL8E
# 214648082   214648082                 :V84-1V31CP.VP0IP
# 214648083   214648083  -PIUVa.ADOR:VGBSF_EVOADPE_CLN2_G
# 214648084   214648084                  3:0CV1-VVQP4P1.I
# 214648085   214648085   Gn_P.2U6_DBOP-SNL_GAVCV:FPI12VR
# 214648086   214648086    SL-IPC3Vd6:VOAV7U_BP_.RG_NPFDG
#
#                          EventTime Status        Value
# 214545234  2024-02-10 08:06:33.335    Bad  Not Connect
# 214545235  2024-02-10 08:06:33.319    Bad  Not Connect
# 214545236  2024-02-10 08:06:33.304    Bad  Not Connect
# 214545237  2024-02-10 08:06:33.304    Bad  Not Connect
# 214545238  2024-02-10 08:06:33.304    Bad  Not Connect
# 214545239  2024-02-10 08:06:33.319    Bad  Not Connect
# 214545240  2024-02-10 08:06:33.304    Bad  Not Connect
# 214545242  2024-02-10 08:06:33.304    Bad  Not Connect
# 214545243  2024-02-10 08:06:33.304    Bad  Not Connect
# 214545244  2024-02-10 08:06:33.304    Bad  Not Connect
# 214545245  2024-02-10 08:06:33.335    Bad  Not Connect
# 214545247  2024-02-10 08:06:33.335    Bad  Not Connect
# 214545248  2024-02-10 08:06:33.304    Bad  Not Connect
# 214545249  2024-02-10 08:06:33.319    Bad  Not Connect
# 214545250  2024-02-10 08:06:33.304    Bad  Not Connect
# 214545251  2024-02-10 08:06:33.304    Bad  Not Connect
# 214545252  2024-02-10 08:06:33.319    Bad  Not Connect
# 214646779  2024-03-05 12:22:09.472    Bad  Not Connect
# 214646781  2024-03-05 12:22:09.472    Bad  Not Connect
# 214646783  2024-03-05 12:22:09.457    Bad  Not Connect
# 214646784  2024-03-05 12:22:09.488    Bad  Not Connect
# 214646786  2024-03-05 12:22:09.488    Bad  Not Connect
# 214646787  2024-03-05 12:22:09.472    Bad  Not Connect
# 214646788  2024-03-05 12:22:09.457    Bad  Not Connect
# 214646789  2024-03-05 12:22:09.457    Bad  Not Connect
# 214646792  2024-03-05 12:22:09.472    Bad  Not Connect
# 214646793  2024-03-05 12:22:09.457    Bad  Not Connect
# 214646794  2024-03-05 12:22:09.472    Bad  Not Connect
# 214648081  2024-03-05 12:22:09.488    Bad  Not Connect
# 214648082  2024-03-05 12:22:09.472    Bad  Not Connect
# 214648083  2024-03-05 12:22:09.457    Bad  Not Connect
# 214648084  2024-03-05 12:22:09.472    Bad  Not Connect
# 214648085  2024-03-05 12:22:09.457    Bad  Not Connect
# 214648086  2024-03-05 12:22:09.457    Bad  Not Connect

# %%
invalid_counts.sum()
# Out:
# 565977

# %%
df2 = df.groupby(df["TagName"])

# %%
df2.EventTime_DT.describe()
# Out:
#                                                     count  \
# TagName
#  13UP1R.:OC2YWCNT7 V7PTDHVAV30                      18587
#  F.:TSRDIKVYRPLTVACT6620S5                            101
#  RVSOU2D 6HD.C2:NY6V5O0PT                             231
#  SD.P6 2DT25OHOVYCT6FRVS:0                             97
#  T1V.C_NX2:E0DSMI_P8PUE                               140
# ...                                                   ...
# yS:L1C0(KT3.4F.3PC)lRdTE.5P                         10933
# yiu(c2elLuS:oSKcTisdSE)C51ltP.3.DPtt0et.aFaRng3nC   16844
# yl:F.E35RT).3PdTC.03C1K(LPS                         13019
# yrStdi.iPcupE).tSlTaCSL0leCcRaG(5t1f13gKa3P:vc.eiF  14088
# ytsKC5cTLScES.dgraF)D3Deh.1P3e1ta.gaieu(0tniRlP...  16859
#
#                                                                              mean  \
# TagName
#  13UP1R.:OC2YWCNT7 V7PTDHVAV30                      2024-05-16 12:45:07.243454464
#  F.:TSRDIKVYRPLTVACT6620S5                          2024-02-13 20:22:40.615990272
#  RVSOU2D 6HD.C2:NY6V5O0PT                           2024-05-20 07:28:38.451779328
#  SD.P6 2DT25OHOVYCT6FRVS:0                          2024-03-14 07:16:36.381072128
#  T1V.C_NX2:E0DSMI_P8PUE                             2024-06-15 22:12:32.636071680
# ...                                                                           ...
# yS:L1C0(KT3.4F.3PC)lRdTE.5P                         2024-06-10 14:51:08.589865216
# yiu(c2elLuS:oSKcTisdSE)C51ltP.3.DPtt0et.aFaRng3nC   2024-07-13 03:30:47.620458240
# yl:F.E35RT).3PdTC.03C1K(LPS                         2024-01-17 18:04:47.855134976
# yrStdi.iPcupE).tSlTaCSL0leCcRaG(5t1f13gKa3P:vc.eiF  2024-03-15 02:49:56.546919424
# ytsKC5cTLScES.dgraF)D3Deh.1P3e1ta.gaieu(0tniRlP...  2024-07-13 03:34:25.275757568
#
#                                                                            min  \
# TagName
#  13UP1R.:OC2YWCNT7 V7PTDHVAV30                      2024-04-29 05:56:21.104000
#  F.:TSRDIKVYRPLTVACT6620S5                          2024-01-30 07:44:57.559000
#  RVSOU2D 6HD.C2:NY6V5O0PT                           2024-04-29 02:19:28.199000
#  SD.P6 2DT25OHOVYCT6FRVS:0                          2024-02-29 01:02:40.162000
#  T1V.C_NX2:E0DSMI_P8PUE                             2024-05-29 02:01:49.517000
# ...                                                                        ...
# yS:L1C0(KT3.4F.3PC)lRdTE.5P                                2024-05-29 00:00:36
# yiu(c2elLuS:oSKcTisdSE)C51ltP.3.DPtt0et.aFaRng3nC          2024-06-28 00:00:41
# yl:F.E35RT).3PdTC.03C1K(LPS                                2024-01-05 15:57:44
# yrStdi.iPcupE).tSlTaCSL0leCcRaG(5t1f13gKa3P:vc.eiF         2024-02-29 00:02:44
# ytsKC5cTLScES.dgraF)D3Deh.1P3e1ta.gaieu(0tniRlP...         2024-06-28 00:00:41
#
#                                                                               25%  \
# TagName
#  13UP1R.:OC2YWCNT7 V7PTDHVAV30                      2024-05-10 18:40:03.078499840
#  F.:TSRDIKVYRPLTVACT6620S5                          2024-02-06 05:20:17.728999936
#  RVSOU2D 6HD.C2:NY6V5O0PT                           2024-05-15 22:07:47.268999936
#  SD.P6 2DT25OHOVYCT6FRVS:0                             2024-03-06 17:25:11.316000
#  T1V.C_NX2:E0DSMI_P8PUE                             2024-06-07 02:11:25.672499968
# ...                                                                           ...
# yS:L1C0(KT3.4F.3PC)lRdTE.5P                                   2024-06-02 22:15:36
# yiu(c2elLuS:oSKcTisdSE)C51ltP.3.DPtt0et.aFaRng3nC   2024-07-05 17:19:22.249999872
# yl:F.E35RT).3PdTC.03C1K(LPS                            2024-01-11 16:54:12.500000
# yrStdi.iPcupE).tSlTaCSL0leCcRaG(5t1f13gKa3P:vc.eiF  2024-03-07 00:25:39.750000128
# ytsKC5cTLScES.dgraF)D3Deh.1P3e1ta.gaieu(0tniRlP...     2024-07-05 17:13:08.500000
#
#                                                                               50%  \
# TagName
#  13UP1R.:OC2YWCNT7 V7PTDHVAV30                      2024-05-16 04:29:17.025999872
#  F.:TSRDIKVYRPLTVACT6620S5                          2024-02-13 14:12:19.913999872
#  RVSOU2D 6HD.C2:NY6V5O0PT                           2024-05-23 16:58:50.540999936
#  SD.P6 2DT25OHOVYCT6FRVS:0                          2024-03-14 01:10:32.387000064
#  T1V.C_NX2:E0DSMI_P8PUE                             2024-06-16 20:07:40.556999936
# ...                                                                           ...
# yS:L1C0(KT3.4F.3PC)lRdTE.5P                                   2024-06-08 15:05:41
# yiu(c2elLuS:oSKcTisdSE)C51ltP.3.DPtt0et.aFaRng3nC      2024-07-13 03:35:38.500000
# yl:F.E35RT).3PdTC.03C1K(LPS                                   2024-01-17 17:32:44
# yrStdi.iPcupE).tSlTaCSL0leCcRaG(5t1f13gKa3P:vc.eiF     2024-03-16 02:18:08.500000
# ytsKC5cTLScES.dgraF)D3Deh.1P3e1ta.gaieu(0tniRlP...            2024-07-13 03:45:41
#
#                                                                               75%  \
# TagName
#  13UP1R.:OC2YWCNT7 V7PTDHVAV30                         2024-05-19 19:44:46.912000
#  F.:TSRDIKVYRPLTVACT6620S5                          2024-02-21 09:02:40.161999872
#  RVSOU2D 6HD.C2:NY6V5O0PT                           2024-05-26 09:42:15.516999936
#  SD.P6 2DT25OHOVYCT6FRVS:0                          2024-03-21 17:10:32.387000064
#  T1V.C_NX2:E0DSMI_P8PUE                             2024-06-26 01:57:41.982000128
# ...                                                                           ...
# yS:L1C0(KT3.4F.3PC)lRdTE.5P                                   2024-06-18 06:45:41
# yiu(c2elLuS:oSKcTisdSE)C51ltP.3.DPtt0et.aFaRng3nC   2024-07-20 13:21:54.750000128
# yl:F.E35RT).3PdTC.03C1K(LPS                            2024-01-23 19:04:12.500000
# yrStdi.iPcupE).tSlTaCSL0leCcRaG(5t1f13gKa3P:vc.eiF  2024-03-22 23:31:54.750000128
# ytsKC5cTLScES.dgraF)D3Deh.1P3e1ta.gaieu(0tniRlP...     2024-07-20 13:40:38.500000
#
#                                                                            max
# TagName
#  13UP1R.:OC2YWCNT7 V7PTDHVAV30                      2024-05-28 19:15:21.841000
#  F.:TSRDIKVYRPLTVACT6620S5                          2024-02-28 17:02:40.162000
#  RVSOU2D 6HD.C2:NY6V5O0PT                           2024-05-28 19:15:42.223000
#  SD.P6 2DT25OHOVYCT6FRVS:0                          2024-03-29 17:10:32.387000
#  T1V.C_NX2:E0DSMI_P8PUE                             2024-06-27 23:56:24.263000
# ...                                                                        ...
# yS:L1C0(KT3.4F.3PC)lRdTE.5P                                2024-06-27 23:55:41
# yiu(c2elLuS:oSKcTisdSE)C51ltP.3.DPtt0et.aFaRng3nC          2024-07-27 23:55:41
# yl:F.E35RT).3PdTC.03C1K(LPS                                2024-01-29 23:57:44
# yrStdi.iPcupE).tSlTaCSL0leCcRaG(5t1f13gKa3P:vc.eiF         2024-03-29 23:55:41
# ytsKC5cTLScES.dgraF)D3Deh.1P3e1ta.gaieu(0tniRlP...         2024-07-27 23:55:41
#
# [7759 rows x 7 columns]

# %%
summary = (
    df.groupby("TagName")["EventTime_DT"]
      .agg(['min', 'max'])
      .assign(LengthInDays=lambda x: x["max"] - x["min"])
      .assign(LengthInSeconds=lambda x: (x["max"] - x["min"]).dt.total_seconds())
      .reset_index()
)
summary
# Out:
#                                                 TagName  \
# 0                         13UP1R.:OC2YWCNT7 V7PTDHVAV30
# 1                             F.:TSRDIKVYRPLTVACT6620S5
# 2                              RVSOU2D 6HD.C2:NY6V5O0PT
# 3                             SD.P6 2DT25OHOVYCT6FRVS:0
# 4                                T1V.C_NX2:E0DSMI_P8PUE
# ...                                                 ...
# 7754                        yS:L1C0(KT3.4F.3PC)lRdTE.5P
# 7755  yiu(c2elLuS:oSKcTisdSE)C51ltP.3.DPtt0et.aFaRng3nC
# 7756                        yl:F.E35RT).3PdTC.03C1K(LPS
# 7757  yrStdi.iPcupE).tSlTaCSL0leCcRaG(5t1f13gKa3P:vc...
# 7758  ytsKC5cTLScES.dgraF)D3Deh.1P3e1ta.gaieu(0tniRl...
#
#                          min                     max            LengthInDays  \
# 0    2024-04-29 05:56:21.104 2024-05-28 19:15:21.841 29 days 13:19:00.737000
# 1    2024-01-30 07:44:57.559 2024-02-28 17:02:40.162 29 days 09:17:42.603000
# 2    2024-04-29 02:19:28.199 2024-05-28 19:15:42.223 29 days 16:56:14.024000
# 3    2024-02-29 01:02:40.162 2024-03-29 17:10:32.387 29 days 16:07:52.225000
# 4    2024-05-29 02:01:49.517 2024-06-27 23:56:24.263 29 days 21:54:34.746000
# ...                      ...                     ...                     ...
# 7754 2024-05-29 00:00:36.000 2024-06-27 23:55:41.000        29 days 23:55:05
# 7755 2024-06-28 00:00:41.000 2024-07-27 23:55:41.000        29 days 23:55:00
# 7756 2024-01-05 15:57:44.000 2024-01-29 23:57:44.000        24 days 08:00:00
# 7757 2024-02-29 00:02:44.000 2024-03-29 23:55:41.000        29 days 23:52:57
# 7758 2024-06-28 00:00:41.000 2024-07-27 23:55:41.000        29 days 23:55:00
#
#       LengthInSeconds
# 0         2553540.737
# 1         2539062.603
# 2         2566574.024
# 3         2563672.225
# 4         2584474.746
# ...               ...
# 7754      2591705.000
# 7755      2591700.000
# 7756      2102400.000
# 7757      2591577.000
# 7758      2591700.000
#
# [7759 rows x 5 columns]

# %%
print("Mean: " + str(summary["LengthInDays"].mean()))
print("Median: " + str(summary["LengthInDays"].median()))
print("Mode: " + str(summary["LengthInDays"].mode()))
print("Min: " + str(summary["LengthInDays"].min()))
print("Max: " + str(summary["LengthInDays"].max()))
# Out:
# Mean: 26 days 04:26:05.923513339
# Median: 29 days 23:30:00
# Mode: 0   0 days
# Name: LengthInDays, dtype: timedelta64[ns]
# Min: 0 days 00:00:00
# Max: 29 days 23:59:59

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,5))
plt.hist(summary["LengthInSeconds"], bins=50)
plt.xlabel("Dauer (Sekunden)")
plt.ylabel("Anzahl Zeitreihen")
plt.title("Verteilung der Zeitreihen-Längen")
plt.tight_layout()
plt.show()

# %%
df_short = summary[summary["LengthInSeconds"] < 2353540.737]

# %%
plt.figure(figsize=(10,5))
plt.hist(df_short["LengthInSeconds"], bins=50)
plt.xlabel("Dauer (Sekunden)")
plt.ylabel("Anzahl Zeitreihen")
plt.title("Verteilung der Zeitreihen-Längen")
plt.tight_layout()
plt.show()

# %%
df["is_numeric"] = pd.to_numeric(df["Value"], errors="coerce").notna()

# %%
table = pd.crosstab(df["Status"], df["is_numeric"])
table.columns = ["String", "Numeric"]
table = table.rename(columns={True: "Numeric", False: "String"})
print(table)
# Out:
#                    String    Numeric
# Status
# Bad                565977     782015
# Good                    0  213642667
# Questionable            0        190
# Substituted, Good       0        253

# %%
percent_table = table.div(table.sum(axis=1), axis=0) * 100
print(percent_table.round(2))
# Out:
#                    String  Numeric
# Status
# Bad                 41.99    58.01
# Good                 0.00   100.00
# Questionable         0.00   100.00
# Substituted, Good    0.00   100.00

# %%
tags_with_strings = (
    df.loc[~df["is_numeric"], "TagName"]
      .dropna()
      .unique()
)
print("Anzahl Tags mit String-Values:", len(tags_with_strings))
# Out:
# Anzahl Tags mit String-Values: 1396
